# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data extracted from the document
data = {
    "Trials": [100, 1000, 10000, 100000, 1000000, 10000000, 100000000],
    "Royal Flush": [0.0, 0.0, 0.0, 0.0, 0.000001, 0.0000012, 0.00000125],
    "Straight Flush": [0.0, 0.0, 0.0, 0.00001, 0.000008, 0.0000126, 0.00001174],
    "Four of a Kind": [0.0, 0.0, 0.0005, 0.00096, 0.000915, 0.0009394, 0.00095106],
    "Full House": [0.0, 0.001, 0.0021, 0.00232, 0.002168, 0.002236, 0.00224806],
    "Flush": [0.0, 0.008, 0.0044, 0.00284, 0.002868, 0.0028792, 0.00284372],
    "Straight": [0.0, 0.004, 0.0032, 0.00297, 0.003135, 0.0031882, 0.00319844],
    "Three of a Kind": [0.02, 0.039, 0.033, 0.03375, 0.033359, 0.0334166, 0.03346342],
    "Two Pair": [0.07, 0.066, 0.0602, 0.05887, 0.058484, 0.0584797, 0.05839841],
    "One Pair": [0.28, 0.428, 0.4256, 0.44584, 0.446704, 0.44791, 0.44758656],
    "Five of a Kind": [0.0, 0.0, 0.0, 0.0, 0.000009, 0.0000088, 0.00000804]
}

# Convert to DataFrame and replace zeros with NaN
df = pd.DataFrame(data).replace(0, np.nan)
df = df.set_index("Trials")

# Set a color palette and line styles
colors = plt.cm.tab10.colors
line_styles = ['-', '--', '-.', ':', '-', '--', '-.', ':', '-', '--']

# Plot all hand types on a single graph for comparison
plt.figure(figsize=(12, 6))

for idx, hand_type in enumerate(df.columns):
    plt.plot(df.index, df[hand_type],
             marker='o', linestyle=line_styles[idx % len(line_styles)],
             color=colors[idx % len(colors)], linewidth=3, label=hand_type)

# Set logarithmic scale for both x-axis and y-axis
plt.xscale("log")
plt.yscale("log")

# Adding labels and title with styling
plt.xlabel("Number of Trials (log scale)", fontsize=14, fontweight='bold')
plt.ylabel("Probability (log scale)", fontsize=14, fontweight='bold')
plt.title("Probability of Different Poker Hands by Number of Trials For Two Identical Decks", fontsize=18, fontweight='bold')

# Adding legend outside of the plot
plt.legend(title="Hand Type", fontsize=12, title_fontsize='14', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data extracted from the document
data = {
    "Trials": [100, 1000, 10000, 100000, 1000000, 10000000, 100000000],
    "Royal Flush": [0.0, 0.0, 0.0, 0.0, 3e-06, 1.6e-06, 1.24e-06],
    "Straight Flush": [0.0, 0.0, 0.0, 2e-05, 1e-05, 1.22e-05, 1.181e-05],
    "Four of a Kind": [0.0, 0.001, 0.001, 0.00088, 0.000932, 0.0009357, 0.00092254],
    "Full House": [0.0, 0.004, 0.0033, 0.00254, 0.002613, 0.0025886, 0.00257247],
    "Flush": [0.0, 0.003, 0.0023, 0.00263, 0.002856, 0.0028924, 0.00284806],
    "Straight": [0.0, 0.002, 0.003, 0.00293, 0.003092, 0.0031902, 0.00320017],
    "Three of a Kind": [0.0, 0.022, 0.0307, 0.03344, 0.033377, 0.0335027, 0.03344786],
    "Two Pair": [0.06, 0.063, 0.0629, 0.05792, 0.058619, 0.0583, 0.05840391],
    "One Pair": [0.48, 0.447, 0.4454, 0.44486, 0.443929, 0.4448707, 0.44490008],
    "Five of a Kind": [0.0, 0.0, 0.0, 1e-05, 7e-06, 7.9e-06, 7.4e-06]
}

# Convert to DataFrame and replace zeros with NaN
df = pd.DataFrame(data).replace(0, np.nan)
df = df.set_index("Trials")

# Set a color palette and line styles
colors = plt.cm.tab10.colors
line_styles = ['-', '--', '-.', ':', '-', '--', '-.', ':', '-', '--']

# Plot all hand types on a single graph for comparison
plt.figure(figsize=(12, 6))

for idx, hand_type in enumerate(df.columns):
    plt.plot(df.index, df[hand_type],
             marker='o', linestyle=line_styles[idx % len(line_styles)],
             color=colors[idx % len(colors)], linewidth=3, label=hand_type)

# Set logarithmic scale for both x-axis and y-axis
plt.xscale("log")
plt.yscale("log")

# Adding labels and title with styling
plt.xlabel("Number of Trials (log scale)", fontsize=14, fontweight='bold')
plt.ylabel("Probability (log scale)", fontsize=14, fontweight='bold')
plt.title("Probability of Different Poker Hands by Number of Trials For Two Distinct Decks", fontsize=18, fontweight='bold')

# Adding legend outside of the plot
plt.legend(title="Hand Type", fontsize=12, title_fontsize='14', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
